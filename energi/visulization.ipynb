# %%
! pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# ...
#   Using cached matplotlib-3.8.2-cp310-cp310-macosx_10_12_x86_64.whl.metadata (5.8 kB)
# ...
#   Using cached contourpy-1.2.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.46.0-cp310-cp310-macosx_10_9_x86_64.whl.metadata (156 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp310-cp310-macosx_10_9_x86_64.whl.metadata (6.4 kB)
# ...
#   Using cached Pillow-10.1.0-cp310-cp310-macosx_10_10_x86_64.whl.metadata (9.5 kB)
# ...
#   Using cached pyparsing-3.1.1-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached seaborn-0.13.0-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.8.2-cp310-cp310-macosx_10_12_x86_64.whl (7.6 MB)
# Using cached contourpy-1.2.0-cp310-cp310-macosx_10_9_x86_64.whl (256 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.46.0-cp310-cp310-macosx_10_9_x86_64.whl (2.3 MB)
# ...

# %%
import pandas as pd
import seaborn as sns

# %%
co2=pd.read_csv('CO2Emis.csv',parse_dates=['Minutes5UTC'])
grid=pd.read_csv('DeclarationGridmix.csv')
production=pd.read_csv('DeclarationProduction.csv')

# %%
co2_time=co2.groupby('Minutes5UTC')['CO2Emission'].sum()
sns.lineplot(co2_time)
# Out:
# <Axes: xlabel='Minutes5UTC', ylabel='CO2Emission'>
